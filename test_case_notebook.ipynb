# %% [markdown]
# # Test case multi-ecehlon inventory control program
# Welcome to this test case of the multi-echelon model implemented within the scope of the Master Thesis called "Comparing single- and multi-echelon methods for inventory control of spare parts at Volvo".
#
# Authors of this project is Jakob Bengtsson and Alexander Larsson, supervisors were Christian Beckers and Johan Lidvall.
#
# This test case displays how to use to program in order to generate optimal reorder-points for an (R,Q) - policy for the example item present in the South African network.
#
# A walkthrough of this test case can give you a brief understanding of the setup of the program and how pieces are connected. However, to really understand what's going on we refer to the theory section (Section 4) of the associated thesis report.

# %%
import pandas as pd
import numpy as np

from src.warehouse_modeling.induced_backorder_cost import *
from src.warehouse_modeling.lead_time_approximation import *
from src.warehouse_modeling.warehouse_optimization import *
from src.warehouse_modeling.warehouse_demand_modeling import *

from src.single_echelon_utils.inventory_level_computation import *
from src.single_echelon_utils.service_level_computation import *
from src.single_echelon_utils.dealer_optimization import *

from utils import *

# %% [markdown]
# ## Initating inputs
# A test case is submitted in the directory "Test_Case". If you have other cases to try out, please enter them here. Remark that even if demand size data is not used (which is the case if demand distribution is Normal, Poisson or NBD) this input is still required by the program. A workaround is to put a placeholder file with demand size of 1 haing probability 100 % as this will not have any effect on the results.
#
# The capital cost used is in percentage per day. The value of 0.15 was given by the supervisors as the holding cost rate in the South African network.

# %%
indata_path = "test_data/test_case_indata.csv"
indata_demand_size_dist_path = "test_data/test_case_indata_demand_sizes.csv"
outdata_path = "test_data/test_case_outdata.csv"
capital_cost = 0.15/365

# %% [markdown]
# Inputs are handled and converted to arrays in the cell below. Note that there are several columns required to exist in the indata file.

# %%
indata_df = pd.read_csv(indata_path)

outdata_df = indata_df.copy()

# Ensure correct columns are present:
required_columns = {"Installation id", "Type", "Name", "Transport time", "Q", 
    "Unit cost", "Target item fill rate", "Demand distribution",	"Demand mean per time unit", "Demand stdev per time unit"}
    
if not required_columns.issubset(set(indata_df.columns.to_list())):
    raise ValueError("Indata doesn't contain all required fields, see documentation.")

# Retrieving the data about dealers.
Q_dealer_arr = indata_df.get(indata_df["Type"] == "Dealer").get("Q").to_numpy().astype("int32")
mu_dealer_arr = indata_df.get(indata_df["Type"] == "Dealer").get("Demand mean per time unit").to_numpy().astype("float64")
demand_type_arr = indata_df.get(indata_df["Type"] == "Dealer").get("Demand distribution").to_numpy()
h_dealer_arr = capital_cost * indata_df.get(indata_df["Type"] == "Dealer").get("Unit cost").to_numpy().astype("float64")
fill_rate_target_arr = indata_df.get(indata_df["Type"] == "Dealer").get("Target item fill rate").to_numpy().astype("float64")
l_dealer_arr = indata_df.get(indata_df["Type"] == "Dealer").get("Transport time").to_numpy().astype("float64")

# If demand distribution is poisson, retrieve 
sigma_dealer_list = []
for id in indata_df.get(indata_df["Type"] == "Dealer").get("Installation id"):
    if str(indata_df.get(indata_df["Installation id"] == id).get("Demand distribution")) == "Poisson":
        sigma_dealer_list.append(math.sqrt(
            float(indata_df.get(outdata_df["Installation id"]== id).get("Demand mean per time unit"))))
    else:
        sigma_dealer_list.append(float(indata_df.get(indata_df["Installation id"] == id).get("Demand stdev per time unit")))        
sigma_dealer_arr = np.array(sigma_dealer_list)

# Input compounding distribution arrays here!
# Supposed to have one row per dealer.
if indata_demand_size_dist_path[-3:] == "csv":
    compounding_dist_df = pd.read_csv(indata_demand_size_dist_path)
else:
    compounding_dist_df = pd.read_excel(indata_path,indata_demand_size_dist_path)

compounding_dist_matrix = compounding_dist_df.to_numpy().T[1:] # Each array is a column in excel, transposing and removing first row holding item amounts.
compounding_dist_matrix = np.nan_to_num(compounding_dist_matrix,copy = True)
# Out:
# C:\Users\PCAdmin\AppData\Local\Temp\ipykernel_11800\3085652986.py:27: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   sigma_dealer_list.append(float(indata_df.get(indata_df["Installation id"] == id).get("Demand stdev per time unit")))

# %% [markdown]
# ## Regional distribution center demand
# The demand at the RDC (or central warehouse in the network) depend on the inventory policies at dealers.
#
# First, as dealers are only demanding Q units, the warehouse demand during the leadtime can only be integer multiples of the smalles common divisor of the dealers order quantities.

# %%
#Find the smallest common divisor of Q.
Q_subbatch_size = find_smallest_divisor(Q_dealer_arr)
print(f"Smallest common divisor of order quantities is: {Q_subbatch_size}")
# Out:
# Smallest common divisor of order quantities is: 1

# %%
   
#Read warehouse values.
L_wh = float(indata_df.get(indata_df["Type"]=="RDC").get("Transport time"))
h_rdc = capital_cost*float(indata_df.get(indata_df["Type"] == "RDC").get("Unit cost"))
Q_0 = int(int(indata_df.get(indata_df["Type"] == "RDC").get("Q"))/Q_subbatch_size) # Observe, Q_0 is in subbatches.

print(f"Leadtime from CDC to RDC is: {L_wh}, holding cost per day at rdc is: {h_rdc} and order quantity is {Q_0}")
# Out:
# Leadtime from CDC to RDC is: 58.0, holding cost per day at rdc is: 0.12380547945205478 and order quantity is 29
# C:\Users\PCAdmin\AppData\Local\Temp\ipykernel_11800\1817249328.py:2: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   L_wh = float(indata_df.get(indata_df["Type"]=="RDC").get("Transport time"))
# C:\Users\PCAdmin\AppData\Local\Temp\ipykernel_11800\1817249328.py:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   h_rdc = capital_cost*float(indata_df.get(indata_df["Type"] == "RDC").get("Unit cost"))
# C:\Users\PCAdmin\AppData\Local\Temp\ipykernel_11800\1817249328.py:4: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   Q_0 = int(int(indata_df.get(indata_df["Type"] == "RDC").get("Q"))/Q_subbatch_size) # Observe, Q_0 is in subbatches.

# %% [markdown]
# With inputs present and Q_subbatch computed, it is time to find the warehouse demand array. This is done in the function "warehouse_subbatch_demand_probability_array" which you can find in directory "warheouse_modeling". The workings of this is thouroughly described in section 4.10 of the report and detailed references can be found in every part of the function in the "warehouse modeling" directory.

# %%
  
# Central warehouse demand
# --------------------------------------------------------------------------
# Computing subbatch demand probability array, distribution, lead time demand mean, and 
# lead time demand variance at central warehouse.
# Observe that these values are returned in "subbatches".
rdc_f_u_probability_array, wh_dist, mu_L, sigma2_L = warehouse_subbatch_demand_probability_array(
Q_dealer_arr, mu_dealer_arr, sigma_dealer_arr, demand_type_arr, L_wh, Q_subbatch_size, 
compounding_dist_matrix)
outdata_df.loc[outdata_df["Type"] == "RDC","Demand distribution"] = wh_dist
outdata_df.loc[outdata_df["Type"] == "RDC","Lead time demand mean"] = mu_L * Q_subbatch_size
outdata_df.loc[outdata_df["Type"] == "RDC","Lead time demand stdev"] = math.sqrt(sigma2_L) * Q_subbatch_size
outdata_df.loc[outdata_df["Type"] == "RDC","Demand mean per time unit"] = mu_L * Q_subbatch_size/L_wh
outdata_df.loc[outdata_df["Type"] == "RDC","Demand stdev per time unit"] = math.sqrt(sigma2_L * Q_subbatch_size/L_wh)
 
print(f"""The demand probability is interpreted like this:

Probability of lead time demand = 0*Q_subbatch is {rdc_f_u_probability_array[0]}
Probability of lead time demand = 1*Q_subbatch is {rdc_f_u_probability_array[1]}
Probability of lead time demand = 2*Q_subbatch is {rdc_f_u_probability_array[2]}
...""")
# Out:
# 2024-10-15 15:38:12,448 - default_log - DEBUG - new_function
# 2024-10-15 15:38:12,449 - sparse_log - DEBUG - warehouse_subbatch_demand_probability_array
# 2024-10-15 15:38:12,450 - default_log - DEBUG - warehouse_demand_mean_approximation
# 2024-10-15 15:38:12,451 - default_log - DEBUG - warehouse_demand_mean_approximation ended.
# 2024-10-15 15:38:12,452 - default_log - DEBUG - warehouse_demand_variance_approximation
# 2024-10-15 15:38:12,452 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:12,453 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:12,985 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,986 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,987 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,987 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,988 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,988 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,989 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,989 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,990 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,991 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,991 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,991 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,992 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,992 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,992 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,993 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,993 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,994 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,994 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,995 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,995 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,996 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,996 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:12,997 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:12,997 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:12,998 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:12,998 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:12,999 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,000 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,000 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,001 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,001 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,002 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,002 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,003 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,003 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,003 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,004 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,004 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,004 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,005 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,005 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,005 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,006 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,012 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,013 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,013 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,014 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,014 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,014 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,016 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,017 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,017 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,018 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,019 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,019 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,020 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,020 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,020 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,021 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,021 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,022 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,022 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,022 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,025 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,025 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,026 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,027 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,028 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,029 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,029 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,030 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,031 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,032 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,032 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,032 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,032 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,033 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,034 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,034 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,035 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,035 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,035 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,036 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,036 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,037 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,037 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,038 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,038 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,039 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,040 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,040 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,040 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,041 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,041 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,042 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,042 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,042 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,043 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,043 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,045 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,046 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,046 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,047 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,047 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,048 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,048 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,049 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,050 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,051 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,051 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,051 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,056 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,057 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,057 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,057 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,058 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,058 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,059 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,060 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,060 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,061 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,062 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,062 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,063 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,063 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,064 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,064 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,065 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,065 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,066 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,066 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,067 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,067 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,067 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,068 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,068 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,069 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,070 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,071 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,073 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,073 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,074 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,075 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,075 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,075 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,076 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,076 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,077 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,078 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,079 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,080 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,080 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,081 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,082 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,083 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,083 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,084 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,085 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,085 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,086 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,086 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,086 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,087 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,087 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,088 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,088 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,088 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,089 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,090 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,090 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,091 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,092 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,092 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,093 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,093 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,094 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,095 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,096 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,097 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,097 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,098 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,101 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,102 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,103 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,104 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,104 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,104 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,105 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,105 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,105 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,106 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,106 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,107 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,107 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,107 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,108 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,108 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,108 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,109 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,109 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,110 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,111 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,111 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,112 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,112 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,114 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,115 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,116 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,117 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,117 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,118 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,118 - default_log - DEBUG - warehouse_demand_variance_term
# 2024-10-15 15:38:13,119 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2024-10-15 15:38:13,119 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,120 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,120 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,120 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,121 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,121 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,121 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,122 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,122 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,123 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,124 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2024-10-15 15:38:13,124 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2024-10-15 15:38:13,125 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand ended.
# 2024-10-15 15:38:13,126 - default_log - DEBUG - warehouse_demand_variance_term ended.
# 2024-10-15 15:38:13,126 - default_log - DEBUG - warehouse_demand_variance_approximation ended.
# 2024-10-15 15:38:13,131 - sparse_log - DEBUG - warehouse_subbatch_demand_probability_array ended.
# 2024-10-15 15:38:13,133 - default_log - DEBUG - new_function ended.
# The demand probability is interpreted like this:
#
# Probability of lead time demand = 0*Q_subbatch is 2.1774057322736473e-19
# Probability of lead time demand = 1*Q_subbatch is 6.015553201084292e-18
# Probability of lead time demand = 2*Q_subbatch is 8.495198857398937e-17
# ...

# %% [markdown]
# ## Induced backorder cost
# When lead time demand at the warehouse is found. The induced backorder cost is required in order to find optimal reorder points R.

# %%
   
# Calculating induced backorder cost.
# --------------------------------------------------------------------------
# Computing shortage costs.
p_dealer_arr = fill_rate_target_arr*h_dealer_arr/(np.ones_like(fill_rate_target_arr)-fill_rate_target_arr)
    
# Computing induced backorder cost for each retailer.
beta_list = []
for h,Q,p,l,my,sigma in zip(h_dealer_arr,Q_dealer_arr,p_dealer_arr,l_dealer_arr,
mu_dealer_arr,sigma_dealer_arr):
    beta_list.append(induced_backorder_cost_opt(h,Q,p,l,my,sigma))
beta_arr = np.array(beta_list)

# Computing weighted backorder cost at central warehouse.
mu_wh = mu_L/L_wh * Q_subbatch_size
beta_rdc = weighting_backorder_cost(mu_dealer_arr,mu_wh,beta_arr)
    
outdata_df.loc[outdata_df["Type"] == "RDC", "Holding cost"] = h_rdc
outdata_df.loc[outdata_df["Type"] == "Dealer", "Holding cost"] = h_dealer_arr
outdata_df.loc[outdata_df["Type"] == "Dealer", "Estimated shortage cost"] = p_dealer_arr
outdata_df.loc[outdata_df["Type"] == "RDC", "Beta"] = beta_rdc
outdata_df.loc[outdata_df["Type"] == "Dealer", "Beta"] = beta_arr

print(f"The induced backorder cost at the RDC is: {beta_rdc}")
# Out:
# 2024-10-15 15:38:28,909 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,911 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,912 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,912 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,913 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,914 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,914 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,915 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,916 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,917 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,918 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,919 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,920 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,921 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,922 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,923 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,924 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,926 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,927 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,928 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,928 - default_log - DEBUG - induced_backorder_cost_opt
# c:\Users\PCAdmin\OneDrive - Latitude 64 AB\Privat\Kodstuga\Master_thesis\src\warehouse_modeling\induced_backorder_cost.py:48: RuntimeWarning: divide by zero encountered in scalar divide
#   g_a = min(0.015*p_norm, max(0.65/np.sqrt(p_norm), 0.05))
# c:\Users\PCAdmin\OneDrive - Latitude 64 AB\Privat\Kodstuga\Master_thesis\src\warehouse_modeling\induced_backorder_cost.py:49: RuntimeWarning: divide by zero encountered in scalar power
#   g_b = max(-1.2, -2*p_norm**(-0.25))
# c:\Users\PCAdmin\OneDrive - Latitude 64 AB\Privat\Kodstuga\Master_thesis\src\warehouse_modeling\induced_backorder_cost.py:81: RuntimeWarning: divide by zero encountered in scalar power
#   k_b = min(0.2, 0.4*p_norm**(-0.35))
# c:\Users\PCAdmin\OneDrive - Latitude 64 AB\Privat\Kodstuga\Master_thesis\src\warehouse_modeling\induced_backorder_cost.py:82: RuntimeWarning: divide by zero encountered in scalar power
#   K = max(1.3, min(2, 2.5*p_norm**(-0.15)))
# 2024-10-15 15:38:28,930 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,931 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,932 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,933 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,934 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,935 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,935 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,936 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,937 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,937 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,938 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,938 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,939 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,939 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,939 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,939 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,940 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,940 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,940 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,941 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,941 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,941 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,942 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,942 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,942 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,942 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,942 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,944 - default_log - DEBUG - induced_backorder_cost_opt
# 2024-10-15 15:38:28,946 - default_log - DEBUG - norm_sigma
# 2024-10-15 15:38:28,947 - default_log - DEBUG - norm_sigma ended.
# 2024-10-15 15:38:28,948 - default_log - DEBUG - induced_backorder_cost_opt ended.
# 2024-10-15 15:38:28,949 - default_log - DEBUG - weighting_backorder_cost
# 2024-10-15 15:38:28,950 - default_log - DEBUG - weighting_backorder_cost ended.
# The induced backorder cost at the RDC is: 0.28001674915125674

# %% [markdown]
# In order to provide a better understanding of the induced backorder cost we here translate is to a fill rate value.

# %%
# Calculating target fill rate corresponding to beta estimate
target_fill_rate_warehouse = beta_rdc/(beta_rdc + h_rdc)
outdata_df.loc[outdata_df["Type"]== "RDC", "Target item fill rate"] = target_fill_rate_warehouse

print(f"The induced backorder cost of {round(beta_rdc,4)} gives a similar reorder point as setting the target fill rate to approximately {100*round(target_fill_rate_warehouse,2)} %")
# Out:
# The induced backorder cost of 0.28 gives a similar reorder point as setting the target fill rate to approximately 69.0 %

# %% [markdown]
# ## Optimizing reorder point at RDC/central warehouse
#
# The optimal reorder point is computed by balancing costs of holding inventory and costs of backorders. The costs of holding inventory increase with more inventory. Backorder costs increase with less inventory.
#
# Here, the induced backorder costs is used to put a value on the backorders.

# %%
# Optimizing reorder point at central warehouse
# --------------------------------------------------------------------------
# Computing optimal reorder points as well as corresponding expected stock on hand 
# and backorders.
R_0 = warehouse_optimization(Q_subbatch_size,Q_0,rdc_f_u_probability_array,h_rdc,beta_rdc)

outdata_df.loc[outdata_df["Type"] == "RDC", "R optimal"] = R_0*Q_subbatch_size
stock_on_hand_wh = positive_inventory(Q_subbatch_size,Q_0,R_0,rdc_f_u_probability_array)
outdata_df.loc[outdata_df["Type"] == "RDC","Expected stock on hand"] = stock_on_hand_wh
    
backorders_wh = negative_inventory(Q_subbatch_size,Q_0,R_0,rdc_f_u_probability_array)
outdata_df.loc[outdata_df["Type"] == "RDC","Expected backorders"] = backorders_wh

print(f"Optimal (R,Q)-policy at RDC is R = {R_0} and Q = {Q_0} ")
# Out:
# 2024-10-15 15:38:50,634 - default_log - DEBUG - new_function
# 2024-10-15 15:38:50,635 - sparse_log - DEBUG - warehouse_optimization
# 2024-10-15 15:38:50,636 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,636 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,637 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,637 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,638 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,640 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,641 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,641 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,643 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,644 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,645 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,646 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,648 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,649 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,650 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,650 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,652 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,653 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,653 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,653 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,655 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,656 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,656 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,658 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,658 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,660 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,661 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,662 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,663 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,664 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,664 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,665 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,666 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,667 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,668 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,669 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,669 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,670 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,670 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,671 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,672 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,672 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,672 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,673 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,673 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,673 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,674 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,674 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,675 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,675 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,675 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,676 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,676 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,677 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,677 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,677 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,678 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,678 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,680 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,682 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,683 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,683 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,685 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,686 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,687 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,687 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,688 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,688 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,689 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,690 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,691 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,691 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,692 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,692 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,692 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,693 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,693 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,693 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,694 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,694 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,694 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,695 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,696 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,697 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,697 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,698 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,698 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,699 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,700 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,701 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,702 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,702 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,703 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,703 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,704 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,704 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,705 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,705 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,706 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,706 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,707 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,707 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,707 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,708 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,708 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,708 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,710 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,711 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,713 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,714 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,715 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,715 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,717 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,717 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,717 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,718 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,718 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,719 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,720 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,720 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,721 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,721 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,722 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,722 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,723 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,724 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,724 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,724 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,725 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,725 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,726 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,727 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,727 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,727 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,728 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,728 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,730 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,730 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,732 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,733 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,734 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,735 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,736 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,737 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,738 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,738 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,739 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,739 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,741 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,741 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,742 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,742 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,742 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,743 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,743 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,744 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,744 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,744 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,745 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,745 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,746 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,747 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,748 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,748 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,749 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,749 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,750 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,751 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,752 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,753 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,755 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,755 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,756 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,757 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,757 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,757 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,758 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,758 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,759 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,759 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,759 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,759 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,760 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,760 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,762 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,764 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,764 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,765 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,766 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,767 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,768 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,768 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,769 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,769 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,771 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,772 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,773 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,774 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,774 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,775 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,775 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,775 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,776 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,776 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,777 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,777 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,777 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,779 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,780 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,781 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,782 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,783 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,784 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,785 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,786 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,787 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,787 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,787 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,788 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,788 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,789 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,789 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,790 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,790 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,791 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,791 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,792 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,792 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,793 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,793 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,795 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,796 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,797 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,797 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,798 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,799 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,799 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,800 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,801 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,801 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,801 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,802 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,802 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,802 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,804 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,805 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,806 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,806 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,807 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,807 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,808 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,808 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,809 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,809 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,809 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,810 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,811 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,811 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,811 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,812 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,813 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,814 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,815 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,816 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,817 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,818 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,818 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,819 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,819 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,820 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,820 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,821 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,821 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,821 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,822 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,822 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,822 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,823 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,823 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,824 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,825 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,826 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,827 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,827 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,828 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,828 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,830 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,831 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,831 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,832 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,832 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,833 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,833 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,835 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,836 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,837 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,838 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,838 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,839 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,839 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,840 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,840 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,841 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,842 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,843 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,844 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,844 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,844 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,845 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,847 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,849 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,849 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,850 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,851 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,851 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,852 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,852 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,853 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,853 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,853 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,854 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,854 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,855 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,857 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,858 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,859 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,859 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,860 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,861 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,861 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,861 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,862 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,863 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,864 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,865 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,866 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,867 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,868 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,869 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,870 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,871 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,871 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,872 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,872 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,872 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,873 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,873 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,874 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,874 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,874 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,875 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,875 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,876 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,876 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,876 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,878 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,879 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,880 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,881 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,883 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,884 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,884 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,885 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,885 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,886 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,886 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,886 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,887 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,888 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,888 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,890 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,891 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,891 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,892 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,892 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,892 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,893 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,894 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,894 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,894 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,895 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,895 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,897 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,897 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,898 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,899 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,900 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,901 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,902 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,903 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,904 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,904 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,905 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,905 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,906 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,906 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,907 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,907 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,907 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,908 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,909 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,909 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,910 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,910 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,913 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,914 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,916 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,917 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,918 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,919 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,920 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,921 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,923 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,923 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,924 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,925 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,926 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,927 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,928 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,929 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,931 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,932 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,934 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,935 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,936 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,937 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,938 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,939 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,940 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,941 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,942 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,943 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,944 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,945 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,946 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,946 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,948 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,949 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,950 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,951 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,952 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,953 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,954 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,955 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,956 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,957 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,958 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,958 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,959 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,959 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,959 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,960 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,960 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,960 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,961 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,961 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,962 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,962 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,963 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,964 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,965 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,966 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,967 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,967 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,968 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,969 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,970 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,971 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,971 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,972 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,973 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,973 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,973 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,974 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,974 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,975 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,975 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,975 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,976 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,976 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,977 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,977 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,978 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,980 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,981 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,983 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,984 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,984 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,985 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,986 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,986 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,987 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,987 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,987 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,988 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,989 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,990 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,991 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,992 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,992 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,993 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,993 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:50,994 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:50,996 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:50,996 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:50,997 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:50,998 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:50,999 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,000 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,001 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,001 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,002 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,002 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,003 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,004 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,005 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,005 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,005 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,006 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,007 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,007 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,008 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,008 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,008 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,009 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,009 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,010 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,011 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,012 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,014 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,015 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,015 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,016 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,017 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,017 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,018 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,018 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,019 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,020 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,020 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,021 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,021 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,022 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,022 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,023 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,023 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,024 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,024 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,025 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,025 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,026 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,026 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,027 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,027 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,028 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,028 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,030 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,031 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,032 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,033 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,034 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,035 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,036 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,036 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,036 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,037 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,037 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,038 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,038 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,039 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,039 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,040 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,041 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,041 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,042 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,043 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,044 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,045 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,046 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,048 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,050 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,050 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,051 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,051 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,052 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,053 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,054 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,054 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,055 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,055 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,056 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,056 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,057 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,058 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,058 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,059 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,060 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,060 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,060 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,061 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,061 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,062 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,063 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,064 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,066 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,067 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,067 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,068 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,069 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,070 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,071 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,071 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,072 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,073 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,073 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,074 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,075 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,075 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,075 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,076 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,076 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,076 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,077 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,078 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,078 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,079 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,080 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,083 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,085 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,086 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,087 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,087 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,088 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,089 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,090 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,091 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,092 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,094 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,096 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,098 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,100 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,101 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,102 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,103 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,105 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,106 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,107 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,108 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,109 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,110 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,111 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,112 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,113 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,114 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,114 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,115 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,116 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,118 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,120 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,121 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,122 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,123 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,124 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,125 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,126 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,127 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,128 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,129 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,130 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,131 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,131 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,132 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,132 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,133 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,134 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,135 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,135 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,136 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,136 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,136 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,137 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,138 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,139 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,139 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,140 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,140 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,141 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,142 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,142 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,143 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,143 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,143 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,144 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,144 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,145 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,146 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,146 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,147 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,148 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,149 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,150 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,150 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,151 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,151 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,152 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,152 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,153 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,153 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,153 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,153 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,154 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,154 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,155 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,155 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,156 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,157 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,158 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,158 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,160 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,160 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,161 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,162 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,163 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,164 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,164 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,165 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,165 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,166 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,167 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,167 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,168 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,169 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,170 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,170 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,171 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,171 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,172 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,172 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,172 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,173 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,173 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,174 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,174 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,174 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,175 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,175 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,177 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,177 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,177 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,178 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,178 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,179 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,180 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,181 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,181 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,183 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,183 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,184 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,184 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,185 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,185 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,185 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,186 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,186 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,187 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,189 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,190 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,190 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,191 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,191 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,192 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,192 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,193 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,193 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,193 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,193 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,194 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,195 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,195 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,196 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,197 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,197 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,200 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,201 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,202 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,202 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,203 - default_log - DEBUG - total_cost
# 2024-10-15 15:38:51,203 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,204 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,205 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,206 - default_log - DEBUG - negative_inventory ended.
# 2024-10-15 15:38:51,207 - default_log - DEBUG - total_cost ended.
# 2024-10-15 15:38:51,208 - sparse_log - DEBUG - warehouse_optimization ended.
# 2024-10-15 15:38:51,208 - default_log - DEBUG - new_function ended.
# 2024-10-15 15:38:51,210 - default_log - DEBUG - positive_inventory
# 2024-10-15 15:38:51,212 - default_log - DEBUG - positive_inventory ended.
# 2024-10-15 15:38:51,213 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:38:51,214 - default_log - DEBUG - negative_inventory ended.
# Optimal (R,Q)-policy at RDC is R = 65 and Q = 29

# %% [markdown]
# ## Computing delay- and lead time
# With the optimal policy in place at the RDC, it is time to compute the actual lead time between RDC and dealers depending on the transportation time between installaitons and the delay due to stockouts at the RDC.

# %%
# Computing expected delay and lead time
# --------------------------------------------------------------------------
W = waiting_time(negative_inventory(Q_subbatch_size,Q_0,R_0,rdc_f_u_probability_array),L_wh,mu_L,Q_subbatch_size)
outdata_df.loc[outdata_df["Type"]== "Dealer", "Expected delay"] = W
lead_time_dealer_arr = outdata_df.get(outdata_df["Type"]== "Dealer").get("Transport time").to_numpy() + W
outdata_df.loc[outdata_df["Type"] == "Dealer", "Lead time"] = lead_time_dealer_arr

# Entering dealer lead time demand and standard deviation.
mu_L_dealer_array = outdata_df.get(outdata_df["Type"] == "Dealer").get("Lead time").to_numpy()*outdata_df.get(
        outdata_df["Type"] == "Dealer").get("Demand mean per time unit").to_numpy()
outdata_df.loc[outdata_df["Type"] == "Dealer", "Lead time demand mean"] = mu_L_dealer_array
    
sqrt_dealer_lead_time_arr = np.sqrt(lead_time_dealer_arr)
outdata_df.loc[outdata_df["Type"] == "Dealer", "Lead time demand stdev"] = sqrt_dealer_lead_time_arr*outdata_df.get(outdata_df["Type"]== "Dealer").get("Demand stdev per time unit").to_numpy()
    
# Entering central warehouse lead time as transport time for completeness.
outdata_df.loc[outdata_df["Type"] == "RDC", "Lead time"] = indata_df.get(indata_df["Type"] == "RDC").get("Transport time")

# Computing MTBA (mean time between arrivals) for use in simulation.
# reference: Axsäter, 2006, Inventory control, eq. 5.4
MTBA_arr = np.zeros_like(mu_L_dealer_array)
for i,mu in enumerate(mu_L_dealer_array):
    compounding_dist_arr = compounding_dist_matrix[i]
    j_arr = np.arange(start=1,stop=len(compounding_dist_arr)+1)
    lam = mu/j_arr.dot(compounding_dist_arr)
    MTBA_arr[i] = 1/lam*lead_time_dealer_arr[i]
outdata_df.loc[outdata_df["Type"]== "Dealer", "MTBA"] = MTBA_arr
# Out:
# 2024-10-15 15:39:04,713 - default_log - DEBUG - negative_inventory
# 2024-10-15 15:39:04,714 - default_log - DEBUG - negative_inventory ended.

# %% [markdown]
# ## Optimizing reorder points at the dealer
# Finally, it is time to find optimal (R,Q)-policies at the dealer by minimizing the holding costs under target service level constraints. The actual optimization is done in "dealer_R_optimization()"

# %%
# Optimizing reorder points at dealer.
# --------------------------------------------------------------------------
# Computing optimal reorder point, expected realised fill rate, and expected 
# stock on hand level.
opt_dealer_list = []
for Q,L_est,fill_rate_target,demand_type,mu,sigma,compounding_dist_arr in zip(Q_dealer_arr,
    lead_time_dealer_arr,fill_rate_target_arr,demand_type_arr, mu_dealer_arr,sigma_dealer_arr, compounding_dist_matrix):
    opt_dealer_list.append(dealer_R_optimization(Q,L_est,fill_rate_target,demand_type,
        mu,demand_variance = math.pow(sigma,2),compounding_dist_arr=compounding_dist_arr))

R_opt_dealer_list,fill_rate_dealer_list,exp_stock_on_hand_list = [],[],[]
for tup in opt_dealer_list:
    R_opt_dealer_list.append(tup[0])
    fill_rate_dealer_list.append(tup[1])
    exp_stock_on_hand_list.append(tup[2])
R_opt_dealer_arr = np.array(R_opt_dealer_list)
fill_rate_dealer_arr = np.array(fill_rate_dealer_list)
exp_stock_on_hand_arr = np.array(exp_stock_on_hand_list)
    

outdata_df.loc[outdata_df["Type"] == "Dealer", "R optimal"] = R_opt_dealer_arr
outdata_df.loc[outdata_df["Type"] == "Dealer", "Realized item fill rate"] = fill_rate_dealer_arr
outdata_df.loc[outdata_df["Type"] == "Dealer", "Expected stock on hand"] = exp_stock_on_hand_arr
    

# Adding expected backorders at retailers.
exp_backorders_dealer_arr = [ 
    expected_backorders_discrete(R,Q,lt_mu,exp_stock_on_hand) for 
    R,Q,lt_mu,exp_stock_on_hand in zip(R_opt_dealer_list,Q_dealer_arr,
    outdata_df.get(outdata_df["Type"] == "Dealer").get("Lead time demand mean").to_numpy(),
    exp_stock_on_hand_list) ]
outdata_df.loc[outdata_df["Type"] == "Dealer", "Expected backorders"] = exp_backorders_dealer_arr

# %% [markdown]
# ## Last touches and output

# %%
# Computing cost expressions
# --------------------------------------------------------------------------
total_holding_cost_dealers_arr = h_dealer_arr*exp_stock_on_hand_arr
total_backorder_cost_dealers_arr = exp_backorders_dealer_arr*p_dealer_arr
outdata_df.loc[outdata_df["Type"] == "Dealer", "Expected holding costs per time unit"] = total_holding_cost_dealers_arr
outdata_df.loc[outdata_df["Type"] == "Dealer", "Expected shortage costs per time unit"] = total_backorder_cost_dealers_arr
outdata_df.loc[outdata_df["Type"] == "Dealer", "Total expected costs"] = total_holding_cost_dealers_arr + total_backorder_cost_dealers_arr
    
outdata_df.loc[outdata_df["Type"] == "RDC", "Expected holding costs per time unit"] = h_rdc*stock_on_hand_wh
outdata_df.loc[outdata_df["Type"] == "RDC", "Total expected costs"] = h_rdc*stock_on_hand_wh

# %%
# Printing results to CSV.
# --------------------------------------------------------------------------

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

if outdata_path is not None:
    outdata_df.to_csv(outdata_path, index = False)

outdataDF = pd.read_csv(outdata_path, index_col = False)
outdataDF
# Out:
#     Unnamed: 0.1  Unnamed: 0 Installation id    Type            Name  \
# 0              0           0               A  Dealer        Bartlett
# 1              1           1               B  Dealer    Bloemfontein
# 2              2           2               C  Dealer        Capetown
# 3              3           3               D  Dealer          Durban
# 4              4           4               E  Dealer          George
# 5              5           5               F  Dealer       Kimberley
# 6              6           6               G  Dealer      Middelburg
# 7              7           7               H  Dealer       Nelspruit
# 8              8           8               I  Dealer  Port Elizabeth
# 9              9           9               J  Dealer    Richards Bay
# 10            10          10               K  Dealer      Rustenburg
# 11            11          11               L  Dealer      Steelpoort
# 12            12          12               M  Dealer   Wolmaransstad
# 13            13          13               Z     RDC    Johannesburg
#
#     Transport time     Q  Unit cost  Target item fill rate  \
# 0                5   9.0     432.90               0.970000
# 1                5   3.0     432.90               0.980000
# 2                5   4.0     432.90               0.980000
# 3                5   4.0     432.90               0.980000
# 4               10   2.0     432.90               0.985000
# 5               10   1.0     432.90               0.000000
# 6               10   6.0     432.90               0.980000
# 7               10   3.0     432.90               0.980000
# 8               10   3.0     432.90               0.980000
# 9               10   3.0     432.90               0.980000
# 10              10   4.0     432.90               0.995000
# 11              10   3.0     432.90               0.980000
# 12              10   4.0     432.90               0.980000
# 13              58  29.0     301.26               0.693416
#
#          Demand distribution  Demand mean per time unit  \
# 0   Empiric_Compound_Poisson                   0.380267
# 1   Empiric_Compound_Poisson                   0.082613
# 2   Empiric_Compound_Poisson                   0.132640
# 3   Empiric_Compound_Poisson                   0.112693
# 4   Empiric_Compound_Poisson                   0.023467
# 5   Empiric_Compound_Poisson                   0.009090
# 6   Empiric_Compound_Poisson                   0.143733
# 7   Empiric_Compound_Poisson                   0.041333
# 8   Empiric_Compound_Poisson                   0.060640
# 9   Empiric_Compound_Poisson                   0.048107
# 10  Empiric_Compound_Poisson                   0.013067
# 11  Empiric_Compound_Poisson                   0.085707
# 12  Empiric_Compound_Poisson                   0.110187
# 13                       NBD                   1.243543
#
#     Demand stdev per time unit Demand type Stocked Inventory policy  \
# 0                     0.641949        Fast     Yes        BABZA__IP
# 1                     0.264094        Fast     Yes        BABZA__IP
# 2                     0.578724        Fast     Yes        BABZA__IP
# 3                     0.463830        Fast     Yes        BABZA__IP
# 4                     0.153782        Fast     Yes        BABZA__IP
# 5                     0.085280        Slow      No        BABZA__IP
# 6                     0.649270     Erratic     Yes        BABZA__IP
# 7                     0.192798        Fast     Yes        BABZA__IP
# 8                     0.317588        Fast     Yes        BABZA__IP
# 9                     0.106715        Fast     Yes        BABZA__IP
# 10                    0.071204        Fast     Yes        BABZA__IP
# 11                    0.778588     Erratic     Yes        BABZA__IP
# 12                    0.455687        Fast     Yes        BABZA__IP
# 13                    1.801801     Erratic     Yes        PDCZA__IP
#
#     Lead time demand mean  Lead time demand stdev  Holding cost  \
# 0                2.914721                1.777276      0.177904
# 1                0.633226                0.731160      0.177904
# 2                1.016677                1.602233      0.177904
# 3                0.863788                1.284142      0.177904
# 4                0.297204                0.547278      0.177904
# 5                0.115124                0.303494      0.177904
# 6                1.820374                2.310612      0.177904
# 7                0.523484                0.686128      0.177904
# 8                0.768002                1.130226      0.177904
# 9                0.609268                0.379774      0.177904
# 10               0.165489                0.253399      0.177904
# 11               1.085470                2.770825      0.177904
# 12               1.395507                1.621691      0.177904
# 13              72.125513               13.722107      0.123805
#
#     Estimated shortage cost      Beta  R optimal  Expected stock on hand  \
# 0                  5.752233  0.151966       13.0               15.136852
# 1                  8.717301  0.276961        2.0                3.368981
# 2                  8.717301  0.427423        4.0                5.491651
# 3                  8.717301  0.368602        3.0                4.639366
# 4                 11.682370  0.425677        2.0                3.202940
# 5                  0.000000  0.000000       -1.0                0.000000
# 6                  8.717301  0.279197        5.0                6.688219
# 7                  8.717301  0.285758        3.0                4.478213
# 8                  8.717301  0.320848        3.0                4.233091
# 9                  8.717301  0.135898        2.0                3.392242
# 10                35.402918  0.441841        2.0                4.334780
# 11                 8.717301  0.556529       13.0               13.921342
# 12                 8.717301  0.253357        4.0                5.106281
# 13                      NaN  0.280017       65.0               11.193966
#
#     Expected backorders  Expected delay  Lead time        MTBA  \
# 0              0.051573        2.664939   7.664939    3.391619
# 1              0.002207        2.664939   7.664939   12.306327
# 2              0.008329        2.664939   7.664939    7.908773
# 3              0.003154        2.664939   7.664939    9.221625
# 4              0.000144        2.664939  12.664939   42.613636
# 5              0.115124        2.664939  12.664939  126.935771
# 6              0.008593        2.664939  12.664939    7.706579
# 7              0.001697        2.664939  12.664939   29.692082
# 8              0.001093        2.664939  12.664939   17.336445
# 9              0.001510        2.664939  12.664939   20.787140
# 10             0.000268        2.664939  12.664939   90.036014
# 11             0.006812        2.664939  12.664939   40.493796
# 12             0.001789        2.664939  12.664939    9.363620
# 13             3.313967             NaN  58.000000         NaN
#
#     Realized item fill rate  Expected holding costs per time unit  \
# 0                  0.972052                              2.692908
# 1                  0.987767                              0.599356
# 2                  0.984468                              0.976987
# 3                  0.990085                              0.825362
# 4                  0.998118                              0.569816
# 5                  0.000000                              0.000000
# 6                  0.985239                              1.189862
# 7                  0.991066                              0.796693
# 8                  0.994433                              0.753084
# 9                  0.990664                              0.603494
# 10                 0.996345                              0.771175
# 11                 0.985710                              2.476664
# 12                 0.993872                              0.908428
# 13                      NaN                              1.385874
#
#     Expected shortage costs per time unit  Total expected costs
# 0                                0.296659              2.989567
# 1                                0.019238              0.618594
# 2                                0.072605              1.049592
# 3                                0.027491              0.852853
# 4                                0.001684              0.571501
# 5                                0.000000              0.000000
# 6                                0.074906              1.264767
# 7                                0.014798              0.811490
# 8                                0.009528              0.762612
# 9                                0.013159              0.616653
# 10                               0.009503              0.780678
# 11                               0.059379              2.536043
# 12                               0.015593              0.924021
# 13                                    NaN              1.385874
