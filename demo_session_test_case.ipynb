# %%
import pandas as pd
from main_program import reorder_point_optimization,reorder_point_optimization_single_echelon
from my_log import *

# %%
#{"1030-61460", "11110022", "11110023", "11110175", "11110283"}

item_code = "11110023"
print(f"Now running item with id: {item_code}")
data_dir = "/Volumes/GoogleDrive/.shortcut-targets-by-id/10oYqI9u7nCLK0q7xF2CvGGIQVokusjaI/Exjobb/7. Data collection"
input_dir = "/item_input_csv_files"
demand_size_dist_dir = "/item_demand_size_distributions_csv_files"

input_path = f"{data_dir}{input_dir}/item_{item_code}_input.csv"
demand_size_dist_path = f"{data_dir}{demand_size_dist_dir}/item_{item_code}_d_size_dist.csv"

input_df = pd.read_csv(input_path)
input_df
# Out:
# Now running item with id: 11110023
#     Unnamed: 0 Installation id    Type            Name  Transport time     Q  \
# 0            0        Bartlett  Dealer        Bartlett               5   9.0
# 1            1    Bloemfontein  Dealer    Bloemfontein               5   3.0
# 2            2        Capetown  Dealer        Capetown               5   4.0
# 3            3          Durban  Dealer          Durban               5   4.0
# 4            4          George  Dealer          George              10   2.0
# 5            5       Kimberley  Dealer       Kimberley              10   1.0
# 6            6      Middelburg  Dealer      Middelburg              10   6.0
# 7            7       Nelspruit  Dealer       Nelspruit              10   3.0
# 8            8  Port Elizabeth  Dealer  Port Elizabeth              10   3.0
# 9            9    Richards Bay  Dealer    Richards Bay              10   3.0
# 10          10      Rustenburg  Dealer      Rustenburg              10   4.0
# ...

# %%
# optimization
import time
start_BM = time.time()
reorder_point_optimization(input_path, indata_demand_size_dist_path=demand_size_dist_path, outdata_path = "test_case_BM_output.csv")
end_BM = time.time()
output_BM_df = pd.read_csv("test_case_BM_output.csv")
reorder_point_optimization_single_echelon(input_path, indata_demand_size_dist_path=demand_size_dist_path, outdata_path = "test_case_SE_output.csv")
output_SE_df = pd.read_csv("test_case_SE_output.csv")

print(f"Multi-echelon model took: {end_BM-start_BM} seconds to run.")
# Out:
# 2022-05-25 13:49:11,105 - default_log - DEBUG - reorder_point_optimization
# 2022-05-25 13:49:11,211 - default_log - DEBUG - new_function
# 2022-05-25 13:49:11,213 - sparse_log - DEBUG - warehouse_subbatch_demand_probability_array
# 2022-05-25 13:49:11,216 - default_log - DEBUG - warehouse_demand_mean_approximation
# 2022-05-25 13:49:11,224 - default_log - DEBUG - warehouse_demand_mean_approximation ended.
# 2022-05-25 13:49:11,227 - default_log - DEBUG - warehouse_demand_variance_approximation
# 2022-05-25 13:49:11,229 - default_log - DEBUG - warehouse_demand_variance_term
# 2022-05-25 13:49:11,260 - default_log - DEBUG - pmf_func_warehouse_subbatch_demand
# 2022-05-25 13:49:13,418 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# 2022-05-25 13:49:13,420 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand ended.
# 2022-05-25 13:49:13,425 - default_log - DEBUG - delta_func_Empiric_Compound_Poisson_demand
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
output_BM_df
# Out:
#     Unnamed: 0.1  Unnamed: 0 Installation id    Type            Name  \
# 0              0           0        Bartlett  Dealer        Bartlett
# 1              1           1    Bloemfontein  Dealer    Bloemfontein
# 2              2           2        Capetown  Dealer        Capetown
# 3              3           3          Durban  Dealer          Durban
# 4              4           4          George  Dealer          George
# 5              5           5       Kimberley  Dealer       Kimberley
# 6              6           6      Middelburg  Dealer      Middelburg
# 7              7           7       Nelspruit  Dealer       Nelspruit
# 8              8           8  Port Elizabeth  Dealer  Port Elizabeth
# 9              9           9    Richards Bay  Dealer    Richards Bay
# 10            10          10      Rustenburg  Dealer      Rustenburg
# 11            11          11      Steelpoort  Dealer      Steelpoort
# 12            12          12   Wolmaransstad  Dealer   Wolmaransstad
# ...

# %%
output_SE_df
# Out:
#     Unnamed: 0.1  Unnamed: 0 Installation id    Type            Name  \
# 0              0           0        Bartlett  Dealer        Bartlett
# 1              1           1    Bloemfontein  Dealer    Bloemfontein
# 2              2           2        Capetown  Dealer        Capetown
# 3              3           3          Durban  Dealer          Durban
# 4              4           4          George  Dealer          George
# 5              5           5       Kimberley  Dealer       Kimberley
# 6              6           6      Middelburg  Dealer      Middelburg
# 7              7           7       Nelspruit  Dealer       Nelspruit
# 8              8           8  Port Elizabeth  Dealer  Port Elizabeth
# 9              9           9    Richards Bay  Dealer    Richards Bay
# 10            10          10      Rustenburg  Dealer      Rustenburg
# 11            11          11      Steelpoort  Dealer      Steelpoort
# 12            12          12   Wolmaransstad  Dealer   Wolmaransstad
# ...
